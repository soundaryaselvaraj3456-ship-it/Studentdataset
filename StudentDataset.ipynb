# %%
from faker import Faker
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.12/dist-packages (40.11.1)

# %%
fake = Faker()
n = 250

# %%
np.random.seed(42)
n=250
data = [{
    "Student_ID": i+1,
    "Name": fake.name(),
    "Gender": np.random.choice(["Male","Female"]),
    "Department": np.random.choice(["CSE","IT","ECE"]),
    "Year": np.random.choice(["1st","2nd","3rd"]),
    "Maths": np.random.randint(40,100),
    "Science": np.random.randint(40,100),
    "English": np.random.randint(40,100),
    "Attendance": np.random.randint(50,101),
    "Internal": np.random.randint(0,26)
} for i in range(n)]

# %%
df = pd.DataFrame(data)

# %%
df["Total"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3

# %%
df["Grade"] = df["Average"].apply(lambda x: "A" if x>=85 else "B" if x>=70 else "C" if x>=50 else "Fail")

# %%
print(df.head())
# Out:
#    Student_ID             Name  Gender Department Year  Maths  Science  \
# 0           1        Tony Ruiz    Male        CSE  3rd     82       47
# 1           2     Jason Norton    Male        ECE  3rd     50       63
# 2           3       Donna Cole  Female        ECE  2nd     92       41
# 3           4    William Watts  Female        CSE  1st     51       97
# 4           5  Cheyenne Vaughn    Male        ECE  3rd     81       67
#
#    English  Attendance  Internal  Total    Average Grade
# 0       60          88        25    189  63.000000     C
# 1       92          85         7    205  68.333333     C
# 2       63          93         5    196  65.333333     C
# 3       61          93        24    209  69.666667     C
# 4       99          65        14    247  82.333333     B

# %%
df
# Out:
#      Student_ID              Name  Gender Department Year  Maths  Science  \
# 0             1         Tony Ruiz    Male        CSE  3rd     82       47
# 1             2      Jason Norton    Male        ECE  3rd     50       63
# 2             3        Donna Cole  Female        ECE  2nd     92       41
# 3             4     William Watts  Female        CSE  1st     51       97
# 4             5   Cheyenne Vaughn    Male        ECE  3rd     81       67
# ..          ...               ...     ...        ...  ...    ...      ...
# 245         246  Dr. Larry Thomas  Female        CSE  3rd     98       87
# 246         247       Diana Chang    Male        CSE  1st     81       75
# 247         248    Angela Mathews    Male        ECE  1st     97       96
# 248         249     Spencer Glass  Female         IT  3rd     92       69
# 249         250        Jimmy Diaz  Female         IT  2nd     52       68
#
#      English  Attendance  Internal  Total    Average Grade
# 0         60          88        25    189  63.000000     C
# 1         92          85         7    205  68.333333     C
# 2         63          93         5    196  65.333333     C
# 3         61          93        24    209  69.666667     C
# 4         99          65        14    247  82.333333     B
# ..       ...         ...       ...    ...        ...   ...
# 245       80          62        10    265  88.333333     A
# 246       66          87         6    222  74.000000     B
# 247       90          80        22    283  94.333333     A
# 248       78          80        17    239  79.666667     B
# 249       51          88         1    171  57.000000     C
#
# [250 rows x 13 columns]

# %%
print("\nTop Students:\n", df.nlargest(5, "Average")[["Name","Average","Grade"]])
# Out:
# Top Students:
#                    Name    Average Grade
# 247     Angela Mathews  94.333333     A
# 211   Michael Robinson  93.000000     A
# 28        Maria Norris  92.000000     A
# 232    Bianca Ferguson  91.666667     A
# 38   Courtney Mitchell  91.333333     A

# %%
plt.scatter(df["Attendance"], df["Average"] , color="purple", label="Students")
plt.xlabel("Attendance" , color="purple")
plt.ylabel("Average Marks", color="purple")
plt.title("Attendance vs Performance" , color="red")
plt.legend()
plt.show()
